# %% [markdown]
# # DataAnalysisAgent Demo
#
# This notebook is a thin demonstration layer. All implementation logic lives in `src/data_analysis_agent/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC_PATH = PROJECT_ROOT / "src"
if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from data_analysis_agent.agent_runner import run_analysis

# %%
result = run_analysis(
    r"C:\Users\pc\OneDrive\Desktop\agent\data\simple_data(1).xlsx",
    verbose=True,
    quality_mode="standard",
)
#报告质量档位：draft、standard、publication
print(result.report_path)
print(result.report_markdown)
# Out:
# [1/7] Loading runtime configuration...
#       Model: deepseek-chat | Tavily search: enabled
# [2/7] Created production run directory...
#       Run root: outputs/run_20260315_160406
# [3/7] Building compact dataset metadata context...
#       Data shape: 1070 rows x 31 columns
# [4/7] Tool registry ready: PythonInterpreterTool, TavilySearchTool
# [5/7] Advanced Data Analyst started reasoning (max steps = 6)
#       Analysis round: 1
#       Step 1/6: thinking...
#       Calling TavilySearchTool | First, search for domain knowledge about NIPT (non-invasive prenatal testing) and Z-scores for chromosomal aneuploidy detection.
#       Completed TavilySearchTool | status = success
#         Observation: Search query: NIPT non-invasive prenatal testing Z-score interpretation for chromosomes 13 18 21 X Y, normal ranges, clinical significance, GC content meaning 1. Improving the calling of non-invasive prenatal testing on
#       Step 2/6: thinking...
# ...
